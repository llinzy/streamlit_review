# %%
# %run random_forest_model.py
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 150 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=-1)]: Done 353 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:  1.6min finished
# {'n_estimators': 460, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 100, 'criterion': 'gini', 'class_weight': 'balanced_subsample', 'bootstrap': False}
#
#
# Top five features of importance:
# [('CHK_ACCT_3', 0.06), ('HISTORY_4', 0.03), ('CHK_ACCT_0', 0.03), ('NEW_CAR', 0.02), ('FURNITURE', 0.02)]
#
# RF Confusion Matrix:
#
#  [[193  16]
#  [ 53  38]]
#
#
#  RF Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.78      0.92      0.85       209
# ...
